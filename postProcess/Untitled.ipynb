# %%
import numpy as np
import scipy.io
import os
import tensorflow as tf
import tensorflow
import h5py
from tensorflow.python import keras
from tensorflow.python.keras.preprocessing import sequence
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Embedding
from tensorflow.python.keras.layers import LSTM
import platform

if platform.system() == "Darwin":
   hf = h5py.File('/Users/csprh/Dlaptop/MATLAB/MYCODE/HAB/WORK/HAB/florida1/LSTMData/LSTMFlor1.h5', 'r')
else:
   hf = h5py.File('/mnt/storage/home/csprh/scratch/HAB/florida1/LSTMData/LSTMFlor1.h5','r')


dataX = hf.get('XLSTMData')
dataY = hf.get('YLSTMData')
dataX = np.array(dataX)
dataY = np.array(dataY)

#np.shape(dataX)
dataX2 = dataX[:,0:1000,:]
np.shape(dataX2)

print(dataY)
print("shape of training set labels: {}",format(dataY.shape))
print("Shape of training set: {}".format(dataX.shape))


print('Build model...')
model = Sequential()
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2, input_shape=(None, 3)))
model.add(Dense(2, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
one_hot_labels = keras.utils.to_categorical(dataY, num_classes=2)
#print(one_hot_labels[:,0])
model.fit(dataX2,one_hot_labels,epochs=200)
#pred = model.predict(dataX)
#predict_classes = np.argmax(pred,axis=1)
#print("Predicted classes: {}",predict_classes)
#print("Expected classes: {}",predict_classes)
# Out:
# [0. 1. 0. 0. 1. 1. 0. 1. 1.]
# shape of training set labels: {} (9,)
# Shape of training set: (9, 3, 10000)
# Build model...
# Train...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2f9304a421a1> in <module>()
#      45 one_hot_labels = keras.utils.to_categorical(dataY, num_classes=2)
#      46 #print(one_hot_labels[:,0])
# ---> 47 model.fit(dataX2,one_hot_labels,epochs=200)
#      48 #pred = model.predict(dataX)
#      49 #predict_classes = np.argmax(pred,axis=1)
#
# ~/tensorflow/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/sequential.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     580         initial_epoch=initial_epoch,
#     581         steps_per_epoch=steps_per_epoch,
# --> 582         validation_steps=validation_steps)
#     583
#     584   def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# ~/tensorflow/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1148         sample_weight=sample_weight,
#    1149         class_weight=class_weight,
# -> 1150         batch_size=batch_size)
#    1151     # Prepare validation data.
#    1152     if validation_data:
#
# ~/tensorflow/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size)
#     782         feed_input_shapes,
#     783         check_batch_axis=False,  # Don't enforce the batch size.
# --> 784         exception_prefix='input')
#     785
#     786     if y is not None:
#
# ~/tensorflow/lib/python3.6/site-packages/tensorflow/python/keras/_impl/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     175                 'Error when checking ' + exception_prefix + ': expected ' +
#     176                 names[i] + ' to have shape ' + str(shape) +
# --> 177                 ' but got array with shape ' + str(data_shape))
#     178   return data
#     179
#
# ValueError: Error when checking input: expected lstm_8_input to have shape (None, 3) but got array with shape (3, 10000)
